# %% [markdown]
# # Jupyter Environment Files

# %% [markdown]
# ## Notebooks

# %%
# !find . -name \*.ipynb | grep -v ./.ipynb_checkpoints | sort
# Out:
# ./01-Download-MAUDE-Data.ipynb
# ./02-Process-2015-Data.ipynb
# ./03-Review-and-Reprocess-2015-Data.ipynb
# ./04-Process-2020-Data.ipynb
# ./04-Process-2021-Data.ipynb
# ./05-Pivot-tables-for-devices-and-defects.ipynb
# ./06-Clean-2020-Data.ipynb
# ./06-Clean-2021-Data.ipynb
# ./07-Install-NLTK.ipynb
# ./08-NLP-2020.ipynb
# ./09-Data-Stratification.ipynb
# ./10-Text-Classification-For-Component-Failures.ipynb
# ./11-Text-Classification-For-Replacements.ipynb
# ./12-PCA-Clustering-v1.ipynb
# ./13-PCA-Clustering-v2.ipynb
# ./14-PCA-Clustering-v3.ipynb
# ./15-Combine-2020-2021-Stratified-Data.ipynb
# ./16-Preprocess-Combined-Data.ipynb
# ./17-PCA-Lemmatized-Sentences.ipynb
# ./18-PCA-Stemmed-Sentences.ipynb
# ./19-LDA-Lemmatized-Sentences.ipynb
# ./20-Word-Cloud-Analysis.ipynb
# ./21-Preprocess-Combined-Data-v2.ipynb
# ./22-PCA-Lemmatized-Sentences-v2.ipynb
# ./23-PCA-Stemmed-Sentences-v2.ipynb
# ./24-PCA-Raw-Text.ipynb
# ./25-PCA.ipynb
# ./26-NMF.ipynb
# ./27-NMF-v2.ipynb
# ...

# %% [markdown]
# ## Directories

# %%
# !ls -d */
# Out:
# 01-Download-MAUDE-Data/
# 02-Process-2015-Data/
# 03-Review-and-Reprocess-2015-Data/
# 04-Process-2020-Data/
# 04-Process-2021-Data/
# 05-Pivot-tables-for-devices-and-defects/
# 06-Clean-2020-Data/
# 06-Clean-2021-Data/
# 08-NLP-2020/
# 09-Data-Stratification/
# 10-Text-Classification-For-Component-Failures/
# 11-Text-Classification-For-Replacements/
# 12-PCA-Clustering-v1/
# 13-PCA-Clustering-v2/
# 14-PCA-Clustering-v3/
# 15-Combine-2020-2021-Stratified-Data/
# 16-Preprocess-Combined-Data/
# 17-PCA-Lemmatized-Sentences/
# 18-PCA-Stemmed-Sentences/
# 19-LDA-Lemmatized-Sentences/
# 21-Preprocess-Combined-Data-v2/
# 22-PCA-Lemmatized-Sentences-v2/
# 23-PCA-Stemmed-Sentences-v2/
# 24-PCA-Raw-Text/
# 25-PCA/
# 26-NMF/
# 27-NMF-v2/
# 28-LDA/
# labeled_data/

# %% [markdown]
# ## Files

# %%
# !find . -type f | grep -v ./.ipynb_checkpoints | grep -v .git | sort
# Out:
# ./01-Download-MAUDE-Data/device2000.zip
# ./01-Download-MAUDE-Data/device2001.zip
# ./01-Download-MAUDE-Data/device2002.zip
# ./01-Download-MAUDE-Data/device2003.zip
# ./01-Download-MAUDE-Data/device2004.zip
# ./01-Download-MAUDE-Data/device2005.zip
# ./01-Download-MAUDE-Data/device2006.zip
# ./01-Download-MAUDE-Data/device2007.zip
# ./01-Download-MAUDE-Data/device2008.zip
# ./01-Download-MAUDE-Data/device2009.zip
# ./01-Download-MAUDE-Data/device2010.zip
# ./01-Download-MAUDE-Data/device2011.zip
# ./01-Download-MAUDE-Data/device2012.zip
# ./01-Download-MAUDE-Data/device2013.zip
# ./01-Download-MAUDE-Data/device2014.zip
# ./01-Download-MAUDE-Data/device2015.zip
# ./01-Download-MAUDE-Data/device2016.zip
# ./01-Download-MAUDE-Data/device2017.zip
# ./01-Download-MAUDE-Data/device2018.zip
# ./01-Download-MAUDE-Data/device2019.zip
# ./01-Download-MAUDE-Data/device2020.zip
# ./01-Download-MAUDE-Data/device2021.zip
# ./01-Download-MAUDE-Data/device2022.zip
# ...
