# %%
import nltk
from nltk.corpus import stopwords

# %%
import pandas as pd

# Identify the data directory, working directory, and data files
data_directory = "./06-Clean-2020-Data"
working_directory = "./08-NLP-2020"
data_file = f"{data_directory}/2020_data_clean.csv"

import os

# Create the working directory if needed
try:
    os.makedirs(working_directory, exist_ok=True)
except OSError as error:
    print(f"Error creating {working_directory}: {error}")

# %%
# Read the data into a pandas dataframe
df = pd.read_csv(
    data_file,  # The data file being read, from the variable assignment above
    on_bad_lines="warn",  # This tells Pandas to only warn on bad lines vs causing an error
    dtype="str",
)  # This tells Pandas to treat all numbers as words

df = df.fillna("")

# %%
# How big is the dataset
df.shape
# Out:
# (3487524, 13)

# %%
df.head()
# Out:
#   Unnamed: 0                                           FOI_TEXT  \
# 0          0  THE RESULTS OF THE INVESTIGATION ARE INCONCLUS...
# 1          1  IT WAS REPORTED THAT THE PATIENT EXPIRED. THER...
# 2          2  INVESTIGATION RESULTS WILL BE PROVIDED IN THE ...
# 3          3  IT WAS REPORTED THAT THE PATIENT CALLED EMERGE...
# 4          4  COMMUNICATION FAILURE AND PREMATURE BATTERY DE...
#
#   DEVICE_PROBLEM_CODE                                DEVICE_PROBLEM_TEXT  \
# 0                2993  Adverse Event Without Identified Device or Use...
# 1                2993  Adverse Event Without Identified Device or Use...
# 2                1332                             Failure to Interrogate
# 3                1332                             Failure to Interrogate
# 4                1332                             Failure to Interrogate
#
#                              GENERIC_NAME DEVICE_REPORT_PRODUCT_CODE  \
# 0                     DEFIBRILLATION LEAD                        LWS
# 1                     DEFIBRILLATION LEAD                        LWS
# 2  IMPLANTABLE CARDIOVERTER DEFIBRILLATOR                        NVZ
# 3  IMPLANTABLE CARDIOVERTER DEFIBRILLATOR                        NVZ
# 4  IMPLANTABLE CARDIOVERTER DEFIBRILLATOR                        NVZ
#
#            UDI-DI      UDI-PUBLIC DATE_OF_EVENT REPORTER_OCCUPATION_CODE  \
# 0  05414734502085  05414734502085    12/12/2019                      001
# 1  05414734502085  05414734502085    12/12/2019                      001
# 2  05414734504386  05414734504386    12/12/2019                      000
# 3  05414734504386  05414734504386    12/12/2019                      000
# 4  05414734504386  05414734504386    12/12/2019                      000
#
#   REPORT_DATE EVENT_LOCATION                    SOURCE_TYPE
# 0                          I  COMPANY REPRESENTATIVE,HEALTH
# 1                          I  COMPANY REPRESENTATIVE,HEALTH
# 2                          I  COMPANY REPRESENTATIVE,HEALTH
# 3                          I  COMPANY REPRESENTATIVE,HEALTH
# 4                          I  COMPANY REPRESENTATIVE,HEALTH

# %% [markdown]
# # Pre-processing Text Data
#
# 1. Remove punctuation
# 2. Tokenization
# 2. Remove stopwords

# %% [markdown]
# ## Remove Punctuation

# %%
# Remove Punctuation
import string

string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# Define a function to remove punctuation in the data
def remove_punctuation(text):
    text = "".join(
        [character for character in text if character not in string.punctuation]
    )
    return text


df["text_clean"] = df["FOI_TEXT"].apply(lambda x: remove_punctuation(x))

# %%
df.head()
# Out:
#   Unnamed: 0                                           FOI_TEXT  \
# 0          0  THE RESULTS OF THE INVESTIGATION ARE INCONCLUS...
# 1          1  IT WAS REPORTED THAT THE PATIENT EXPIRED. THER...
# 2          2  INVESTIGATION RESULTS WILL BE PROVIDED IN THE ...
# 3          3  IT WAS REPORTED THAT THE PATIENT CALLED EMERGE...
# 4          4  COMMUNICATION FAILURE AND PREMATURE BATTERY DE...
#
#   DEVICE_PROBLEM_CODE                                DEVICE_PROBLEM_TEXT  \
# 0                2993  Adverse Event Without Identified Device or Use...
# 1                2993  Adverse Event Without Identified Device or Use...
# 2                1332                             Failure to Interrogate
# 3                1332                             Failure to Interrogate
# 4                1332                             Failure to Interrogate
#
#                              GENERIC_NAME DEVICE_REPORT_PRODUCT_CODE  \
# 0                     DEFIBRILLATION LEAD                        LWS
# 1                     DEFIBRILLATION LEAD                        LWS
# 2  IMPLANTABLE CARDIOVERTER DEFIBRILLATOR                        NVZ
# 3  IMPLANTABLE CARDIOVERTER DEFIBRILLATOR                        NVZ
# 4  IMPLANTABLE CARDIOVERTER DEFIBRILLATOR                        NVZ
#
#            UDI-DI      UDI-PUBLIC DATE_OF_EVENT REPORTER_OCCUPATION_CODE  \
# 0  05414734502085  05414734502085    12/12/2019                      001
# 1  05414734502085  05414734502085    12/12/2019                      001
# 2  05414734504386  05414734504386    12/12/2019                      000
# 3  05414734504386  05414734504386    12/12/2019                      000
# 4  05414734504386  05414734504386    12/12/2019                      000
#
#   REPORT_DATE EVENT_LOCATION                    SOURCE_TYPE  \
# 0                          I  COMPANY REPRESENTATIVE,HEALTH
# 1                          I  COMPANY REPRESENTATIVE,HEALTH
# 2                          I  COMPANY REPRESENTATIVE,HEALTH
# 3                          I  COMPANY REPRESENTATIVE,HEALTH
# 4                          I  COMPANY REPRESENTATIVE,HEALTH
#
#                                           text_clean
# 0  THE RESULTS OF THE INVESTIGATION ARE INCONCLUS...
# 1  IT WAS REPORTED THAT THE PATIENT EXPIRED THERE...
# 2  INVESTIGATION RESULTS WILL BE PROVIDED IN THE ...
# 3  IT WAS REPORTED THAT THE PATIENT CALLED EMERGE...
# 4  COMMUNICATION FAILURE AND PREMATURE BATTERY DE...

# %% [markdown]
# ## Expanding Contraction and Tokenize

# %%
import contractions

# This approach takes the FOI_TEXT as a string and creates a new column with tokens
# That is, it removes the contraction _and_ tokenizes at the same time
# no additional function is needed, x.split tokenizes the string (FOI text) at every space

df["no_contractions"] = df["FOI_TEXT"].apply(
    lambda x: [contractions.fix(word) for word in x.split()]
)
df.head()
# Out:
#   Unnamed: 0                                           FOI_TEXT  \
# 0          0  THE RESULTS OF THE INVESTIGATION ARE INCONCLUS...
# 1          1  IT WAS REPORTED THAT THE PATIENT EXPIRED. THER...
# 2          2  INVESTIGATION RESULTS WILL BE PROVIDED IN THE ...
# 3          3  IT WAS REPORTED THAT THE PATIENT CALLED EMERGE...
# 4          4  COMMUNICATION FAILURE AND PREMATURE BATTERY DE...
#
#   DEVICE_PROBLEM_CODE                                DEVICE_PROBLEM_TEXT  \
# 0                2993  Adverse Event Without Identified Device or Use...
# 1                2993  Adverse Event Without Identified Device or Use...
# 2                1332                             Failure to Interrogate
# 3                1332                             Failure to Interrogate
# 4                1332                             Failure to Interrogate
#
#                              GENERIC_NAME DEVICE_REPORT_PRODUCT_CODE  \
# 0                     DEFIBRILLATION LEAD                        LWS
# 1                     DEFIBRILLATION LEAD                        LWS
# 2  IMPLANTABLE CARDIOVERTER DEFIBRILLATOR                        NVZ
# 3  IMPLANTABLE CARDIOVERTER DEFIBRILLATOR                        NVZ
# 4  IMPLANTABLE CARDIOVERTER DEFIBRILLATOR                        NVZ
#
#            UDI-DI      UDI-PUBLIC DATE_OF_EVENT REPORTER_OCCUPATION_CODE  \
# 0  05414734502085  05414734502085    12/12/2019                      001
# 1  05414734502085  05414734502085    12/12/2019                      001
# 2  05414734504386  05414734504386    12/12/2019                      000
# 3  05414734504386  05414734504386    12/12/2019                      000
# 4  05414734504386  05414734504386    12/12/2019                      000
#
#   REPORT_DATE EVENT_LOCATION                    SOURCE_TYPE  \
# 0                          I  COMPANY REPRESENTATIVE,HEALTH
# 1                          I  COMPANY REPRESENTATIVE,HEALTH
# 2                          I  COMPANY REPRESENTATIVE,HEALTH
# 3                          I  COMPANY REPRESENTATIVE,HEALTH
# 4                          I  COMPANY REPRESENTATIVE,HEALTH
#
#                                           text_clean  \
# 0  THE RESULTS OF THE INVESTIGATION ARE INCONCLUS...
# 1  IT WAS REPORTED THAT THE PATIENT EXPIRED THERE...
# 2  INVESTIGATION RESULTS WILL BE PROVIDED IN THE ...
# 3  IT WAS REPORTED THAT THE PATIENT CALLED EMERGE...
# 4  COMMUNICATION FAILURE AND PREMATURE BATTERY DE...
#
#                                      no_contractions
# 0  [THE, RESULTS, OF, THE, INVESTIGATION, ARE, IN...
# 1  [IT, WAS, REPORTED, THAT, THE, PATIENT, EXPIRE...
# 2  [INVESTIGATION, RESULTS, WILL, BE, PROVIDED, I...
# 3  [IT, WAS, REPORTED, THAT, THE, PATIENT, CALLED...
# 4  [COMMUNICATION, FAILURE, AND, PREMATURE, BATTE...

# %%
# Define a function to split our sentences into a list of words
import re


def tokenize(text):
    tokens = re.split("\W+", text)
    return tokens


# df['text_tokenized'] = data['text_clean'].apply(lambda x: tokenize(x.lower()))

# %%
df.head()
# Out:
#   Unnamed: 0                                           FOI_TEXT  \
# 0          0  THE RESULTS OF THE INVESTIGATION ARE INCONCLUS...
# 1          1  IT WAS REPORTED THAT THE PATIENT EXPIRED. THER...
# 2          2  INVESTIGATION RESULTS WILL BE PROVIDED IN THE ...
# 3          3  IT WAS REPORTED THAT THE PATIENT CALLED EMERGE...
# 4          4  COMMUNICATION FAILURE AND PREMATURE BATTERY DE...
#
#   DEVICE_PROBLEM_CODE                                DEVICE_PROBLEM_TEXT  \
# 0                2993  Adverse Event Without Identified Device or Use...
# 1                2993  Adverse Event Without Identified Device or Use...
# 2                1332                             Failure to Interrogate
# 3                1332                             Failure to Interrogate
# 4                1332                             Failure to Interrogate
#
#                              GENERIC_NAME DEVICE_REPORT_PRODUCT_CODE  \
# 0                     DEFIBRILLATION LEAD                        LWS
# 1                     DEFIBRILLATION LEAD                        LWS
# 2  IMPLANTABLE CARDIOVERTER DEFIBRILLATOR                        NVZ
# 3  IMPLANTABLE CARDIOVERTER DEFIBRILLATOR                        NVZ
# 4  IMPLANTABLE CARDIOVERTER DEFIBRILLATOR                        NVZ
#
#            UDI-DI      UDI-PUBLIC DATE_OF_EVENT REPORTER_OCCUPATION_CODE  \
# 0  05414734502085  05414734502085    12/12/2019                      001
# 1  05414734502085  05414734502085    12/12/2019                      001
# 2  05414734504386  05414734504386    12/12/2019                      000
# 3  05414734504386  05414734504386    12/12/2019                      000
# 4  05414734504386  05414734504386    12/12/2019                      000
#
#   REPORT_DATE EVENT_LOCATION                    SOURCE_TYPE  \
# 0                          I  COMPANY REPRESENTATIVE,HEALTH
# 1                          I  COMPANY REPRESENTATIVE,HEALTH
# 2                          I  COMPANY REPRESENTATIVE,HEALTH
# 3                          I  COMPANY REPRESENTATIVE,HEALTH
# 4                          I  COMPANY REPRESENTATIVE,HEALTH
#
#                                           text_clean  \
# 0  THE RESULTS OF THE INVESTIGATION ARE INCONCLUS...
# 1  IT WAS REPORTED THAT THE PATIENT EXPIRED THERE...
# 2  INVESTIGATION RESULTS WILL BE PROVIDED IN THE ...
# 3  IT WAS REPORTED THAT THE PATIENT CALLED EMERGE...
# 4  COMMUNICATION FAILURE AND PREMATURE BATTERY DE...
#
#                                      no_contractions
# 0  [THE, RESULTS, OF, THE, INVESTIGATION, ARE, IN...
# 1  [IT, WAS, REPORTED, THAT, THE, PATIENT, EXPIRE...
# 2  [INVESTIGATION, RESULTS, WILL, BE, PROVIDED, I...
# 3  [IT, WAS, REPORTED, THAT, THE, PATIENT, CALLED...
# 4  [COMMUNICATION, FAILURE, AND, PREMATURE, BATTE...

# %%
df.loc[:, ["FOI_TEXT", "text_clean", "no_contractions"]].head()
# Out:
#                                             FOI_TEXT  \
# 0  THE RESULTS OF THE INVESTIGATION ARE INCONCLUS...
# 1  IT WAS REPORTED THAT THE PATIENT EXPIRED. THER...
# 2  INVESTIGATION RESULTS WILL BE PROVIDED IN THE ...
# 3  IT WAS REPORTED THAT THE PATIENT CALLED EMERGE...
# 4  COMMUNICATION FAILURE AND PREMATURE BATTERY DE...
#
#                                           text_clean  \
# 0  THE RESULTS OF THE INVESTIGATION ARE INCONCLUS...
# 1  IT WAS REPORTED THAT THE PATIENT EXPIRED THERE...
# 2  INVESTIGATION RESULTS WILL BE PROVIDED IN THE ...
# 3  IT WAS REPORTED THAT THE PATIENT CALLED EMERGE...
# 4  COMMUNICATION FAILURE AND PREMATURE BATTERY DE...
#
#                                      no_contractions
# 0  [THE, RESULTS, OF, THE, INVESTIGATION, ARE, IN...
# 1  [IT, WAS, REPORTED, THAT, THE, PATIENT, EXPIRE...
# 2  [INVESTIGATION, RESULTS, WILL, BE, PROVIDED, I...
# 3  [IT, WAS, REPORTED, THAT, THE, PATIENT, CALLED...
# 4  [COMMUNICATION, FAILURE, AND, PREMATURE, BATTE...

# %% [markdown]
# ## Remove Stopwords

# %%
# Remove Stopwords
stopwords = nltk.corpus.stopwords.words("english")

stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# Define a function to remove all stopwords
def remove_stopwords(tokenized_text):
    text = [word.lower() for word in tokenized_text if word.lower() not in stopwords]
    return text


df["text_nostop"] = df["no_contractions"].apply(lambda x: remove_stopwords(x))

# %%
df.loc[:, ["FOI_TEXT", "text_nostop"]].head()

# %%
# Parts of Speech Tagging (POS)

# def pos_tag(tagged_text):
# return nltk.pos_tag(tagged_text)

df["pos_text"] = df["text_nostop"].apply(lambda x: nltk.pos_tag(x))

# %%
df.loc[:, ["FOI_TEXT", "pos_text"]].head()

# %% [markdown]
# # lemmatization

# %%
# Use the wordnet Library to map words to their Lemmatization form

nltk.download("wordnet")
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
df["lemmatized"] = df["text_nostop"].apply(
    lambda x: [lemmatizer.lemmatize(word) for word in x]
)

# %%
df.loc[:, ["FOI_TEXT", "lemmatized"]].head()
